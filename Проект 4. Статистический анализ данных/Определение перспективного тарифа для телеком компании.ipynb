# %% [markdown]
# # Определение перспективного тарифа для телеком-компании

# %% [markdown]
# >[Определение перспективного тарифа для телеком-компании](#scrollTo=uVbDwAI833cb)
#
# >>[Шаг 1. Откройте файл с данными и изучите общую информацию](#scrollTo=NzOeQM6C_oCY)
#
# >>[Шаг 2. Подготовьте данные](#scrollTo=Y0kllEng_oCf)
#
# >>[Шаг 3. Исследовательский анализ данных](#scrollTo=GF37Inq-_oCn)
#
# >>[Шаг 4. Проверка гипотез](#scrollTo=aKJz6DhN_oCr)
#
# >>[Шаг 5. Общий вывод](#scrollTo=pG1MF9I0lPbQ)

# %% [markdown]
# В нашем распоряжении данные «Мегалайна» — федерального оператора сотовой связи. Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег. Необохдимо сделать предварительный анализ тарифов на небольшой выборке клиентов. В распоряжении имеются данные 500 пользователей «Мегалайна»: кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год. Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.
#
# В ходе выполнения данного проекта необходимо:
# - Открыть файл с данными и изучить общую информацию;
# - Подготовить данные к нужному виду;
# - Проанализировать данные;
# - Проверить данные на гипотезы;
# - Написать общий вывод.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

# %%
pd.set_option('display.max_columns', None) # код для отображения всех столбцов датафреймов

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию

# %% [markdown]
# **Задание 1.** Откройте файл `/datasets/calls.csv`, сохраните датафрейм в переменную `calls`.

# %%
calls = pd.read_csv('/datasets/calls.csv')

# %% [markdown]
# **Задание 2.** Выведите первые 5 строк датафрейма `calls`.

# %%
calls.head()
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000

# %% [markdown]
# **Задание 3.** Выведите основную информацию для датафрейма `calls` с помощью метода `info()`.

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# **Задание 4.** С помощью метода `hist()` выведите гистограмму для столбца с продолжительностью звонков. Подумайте о том, как распределены данные.

# %%
calls['duration'].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Задание 5.** Откройте файл `/datasets/internet.csv`, сохраните датафрейм в переменную `sessions`.

# %%
sessions = pd.read_csv('/datasets/internet.csv')

# %% [markdown]
# **Задание 6.** Выведите первые 5 строк датафрейма `sessions`.

# %%
sessions.head()
# Out:
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000

# %% [markdown]
# **Задание 7.** Выведите основную информацию для датафрейма `sessions` с помощью метода `info()`.

# %%
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB

# %% [markdown]
# **Задание 8.** С помощью метода `hist()` выведите гистограмму для столбца с количеством потраченных мегабайт.

# %%
sessions['mb_used'].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Задание 9.** Откройте файл `/datasets/messages.csv`, сохраните датафрейм в переменную `messages`.

# %%
messages = pd.read_csv('/datasets/messages.csv')

# %% [markdown]
# **Задание 10.** Выведите первые 5 строк датафрейма `messages`.

# %%
messages.head()
# Out:
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000

# %% [markdown]
# **Задание 11.** Выведите основную информацию для датафрейма `messages` с помощью метода `info()`.

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# **Задание 12.** Откройте файл `/datasets/tariffs.csv`, сохраните датафрейм в переменную `tariffs`.

# %%
tariffs = pd.read_csv('/datasets/tariffs.csv')

# %% [markdown]
# **Задание 13.** Выведите весь датафрейм `tariffs`.

# %%
tariffs
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %% [markdown]
# **Задание 14.** Выведите основную информацию для датафрейма `tariffs` с помощью метода `info()`.

# %%
tariffs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   rub_monthly_fee        2 non-null      int64
#  4   rub_per_gb             2 non-null      int64
#  5   rub_per_message        2 non-null      int64
#  6   rub_per_minute         2 non-null      int64
#  7   tariff_name            2 non-null      object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes

# %% [markdown]
# **Задание 15.** Откройте файл `/datasets/users.csv`, сохраните датафрейм в переменную `users`.

# %%
users = pd.read_csv('/datasets/users.csv')

# %% [markdown]
# **Задание 16.** Выведите первые 5 строк датафрейма `users`.

# %%
users.head(5)
# Out:
#    user_id  age churn_date         city first_name  last_name    reg_date  \
# 0     1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1     1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2     1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3     1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4     1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra

# %% [markdown]
# **Задание 17.** Выведите основную информацию для датафрейма `users` с помощью метода `info()`.

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %% [markdown]
# **Вывод к шагу 1**
# На шаге 1 загрузили датафреймы calls, sessions, messages, tariffs и users и отобразили по ним основную информацию.

# %% [markdown]
# ## Шаг 2. Подготовьте данные

# %% [markdown]
# **Задание 18.**  Приведите столбцы
#
# - `reg_date` из таблицы `users`
# - `churn_date` из таблицы `users`
# - `call_date` из таблицы `calls`
# - `message_date` из таблицы `messages`
# - `session_date` из таблицы `sessions`
#
# к новому типу с помощью метода `to_datetime()`.

# %%
# обработка столбца reg_date
users['reg_date'] = pd.to_datetime(users['reg_date'], format='%Y-%m-%d')
users.info()
print()
# обработка столбца churn_date
users['churn_date'] = pd.to_datetime(users['churn_date'], format='%Y-%m-%d')
users.info()
print()
# обработка столбца call_date
calls['call_date'] = pd.to_datetime(calls['call_date'], format='%Y-%m-%d')
calls.info()
print()
# обработка столбца message_date
messages['message_date'] = pd.to_datetime(messages['message_date'], format='%Y-%m-%d')
messages.info()
print()
# обработка столбца session_date
sessions['session_date'] = pd.to_datetime(sessions['session_date'], format='%Y-%m-%d')
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    datetime64[ns]
#  7   tariff      500 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 31.4+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     datetime64[ns]
#  3   city        500 non-null    object
# ...

# %% [markdown]
# **Задание 19.** В данных вы найдёте звонки с нулевой продолжительностью. Это не ошибка: нулями обозначены пропущенные звонки, поэтому их не нужно удалять.
#
# Однако в столбце `duration` датафрейма `calls` значения дробные. Округлите значения столбца `duration` вверх с помощью метода `numpy.ceil()` и приведите столбец `duration` к типу `int`.

# %%
# округление значений столбца duration с помощью np.ceil() и приведение типа к int
calls['duration'] = np.ceil(calls['duration']).astype('int')
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  datetime64[ns]
#  2   duration   202607 non-null  int64
#  3   user_id    202607 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 6.2+ MB

# %% [markdown]
# **Задание 20.** Удалите столбец `Unnamed: 0` из датафрейма `sessions`. Столбец с таким названием возникает, когда данные сохраняют с указанием индекса (`df.to_csv(..., index=column)`). Он сейчас не понадобится.

# %%
sessions = sessions.drop(['Unnamed: 0'], axis=1)
sessions.head()
# Out:
#        id  mb_used session_date  user_id
# 0  1000_0   112.95   2018-11-25     1000
# 1  1000_1  1052.81   2018-09-07     1000
# 2  1000_2  1197.26   2018-06-25     1000
# 3  1000_3   550.27   2018-08-22     1000
# 4  1000_4   302.56   2018-09-24     1000

# %% [markdown]
# **Задание 21.** Создайте столбец `month` в датафрейме `calls` с номером месяца из столбца `call_date`.

# %%
calls['month'] = calls['call_date'].dt.month
calls.head()
# Out:
#        id  call_date  duration  user_id  month
# 0  1000_0 2018-07-25         0     1000      7
# 1  1000_1 2018-08-17         0     1000      8
# 2  1000_2 2018-06-11         3     1000      6
# 3  1000_3 2018-09-21        14     1000      9
# 4  1000_4 2018-12-15         6     1000     12

# %% [markdown]
# **Задание 22.** Создайте столбец `month` в датафрейме `messages` с номером месяца из столбца `message_date`.

# %%
messages['month'] = messages['message_date'].dt.month
messages.head()
# Out:
#        id message_date  user_id  month
# 0  1000_0   2018-06-27     1000      6
# 1  1000_1   2018-10-08     1000     10
# 2  1000_2   2018-08-04     1000      8
# 3  1000_3   2018-06-16     1000      6
# 4  1000_4   2018-12-05     1000     12

# %% [markdown]
# **Задание 23.** Создайте столбец `month` в датафрейме `sessions` с номером месяца из столбца `session_date`.

# %%
sessions['month'] = sessions['session_date'].dt.month
sessions.head()
# Out:
#        id  mb_used session_date  user_id  month
# 0  1000_0   112.95   2018-11-25     1000     11
# 1  1000_1  1052.81   2018-09-07     1000      9
# 2  1000_2  1197.26   2018-06-25     1000      6
# 3  1000_3   550.27   2018-08-22     1000      8
# 4  1000_4   302.56   2018-09-24     1000      9

# %% [markdown]
# **Задание 24.** Посчитайте количество сделанных звонков разговора для каждого пользователя по месяцам.

# %%
# подсчёт количества звонков для каждого пользователя по месяцам
calls_per_month = calls.groupby(['user_id','month']).agg(calls=('duration', 'count'))  #['duration'].count()

# %%
calls_per_month.head(30) # вывод 30 первых строк на экран
# Out:
#                calls
# user_id month
# 1000    5         22
#         6         43
#         7         47
#         8         52
#         9         58
#         10        57
#         11        43
#         12        46
# 1001    11        59
#         12        63
# 1002    6         15
#         7         26
#         8         42
#         9         36
#         10        33
#         11        32
#         12        33
# 1003    8         55
#         9        134
#         10       108
#         11       115
#         12       108
# 1004    5          9
#         6         31
#         7         22
#         8         19
#         9         26
#         10        29
#         11        19
#         12        21

# %% [markdown]
# **Задание 25.** Посчитайте количество израсходованных минут разговора для каждого пользователя по месяцам и сохраните в переменную `minutes_per_month`. Вам понадобится
#
# - сгруппировать датафрейм с информацией о звонках по двум столбцам — с идентификаторами пользователей и номерами месяцев;
# - после группировки выбрать столбец `duration`
# - затем применить метод для подсчёта суммы.
#
# Выведите первые 30 строчек `minutes_per_month`.

# %%
# подсчёт израсходованных минут для каждого пользователя по месяцам
minutes_per_month = calls.groupby(['user_id','month']).agg(minutes=('duration','sum'))

# %%
minutes_per_month.head(30) # вывод первых 30 строк на экран
# Out:
#                minutes
# user_id month
# 1000    5          159
#         6          172
#         7          340
#         8          408
#         9          466
#         10         350
#         11         338
#         12         333
# 1001    11         430
#         12         414
# 1002    6          117
#         7          214
#         8          289
#         9          206
#         10         212
#         11         243
#         12         236
# 1003    8          380
#         9          961
#         10         855
#         11         824
#         12         802
# 1004    5           35
#         6          171
#         7          135
#         8          137
#         9          117
#         10         145
#         11         117
#         12         130

# %% [markdown]
# **Задание 26.** Посчитайте количество отправленных сообщений по месяцам для каждого пользователя и сохраните в переменную `messages_per_month`. Вам понадобится
#
# - сгруппировать датафрейм с информацией о сообщениях по двум столбцам — с идентификаторами пользователей и номерами месяцев;
# - после группировки выбрать столбец `message_date`;
# - затем применить метод для подсчёта количества.
#
# Выведите первые 30 строчек `messages_per_month`.

# %%
# подсчёт количества отправленных сообщений для каждого пользователя по месяцам
messages_per_month = messages.groupby(['user_id','month']).agg(messages=('message_date', 'count'))

# %%
messages_per_month.head(30) # вывод первых 30 строк на экран
# Out:
#                messages
# user_id month
# 1000    5            22
#         6            60
#         7            75
#         8            81
#         9            57
#         10           73
#         11           58
#         12           70
# 1002    6             4
#         7            11
#         8            13
#         9             4
#         10           10
#         11           16
#         12           12
# 1003    8            37
#         9            91
#         10           83
#         11           94
#         12           75
# 1004    5            95
#         6           134
#         7           181
#         8           151
#         9           146
#         10          165
#         11          158
#         12          162
# 1005    1             7
#         2            38

# %% [markdown]
# **Задание 27.** Посчитайте количество потраченных мегабайт по месяцам для каждого пользователя и сохраните в переменную `sessions_per_month`. Вам понадобится
#
# - сгруппировать датафрейм с информацией о сообщениях по двум столбцам — с идентификаторами пользователей и номерами месяцев;
# - затем применить метод для подсчёта суммы: `.agg({'mb_used': 'sum'})`

# %%
# подсчёт потраченных мегабайт для каждого пользователя по месяцам
sessions_per_month = sessions.groupby(['user_id','month']).agg({'mb_used':'sum'})

# %%
sessions_per_month.head(30) # вывод первых 30 строк на экран
# Out:
#                 mb_used
# user_id month
# 1000    5       2253.49
#         6      23233.77
#         7      14003.64
#         8      14055.93
#         9      14568.91
#         10     14702.49
#         11     14756.47
#         12      9817.61
# 1001    11     18429.34
#         12     14036.66
# 1002    6      10856.82
#         7      17580.10
#         8      20319.26
#         9      16691.08
#         10     13888.25
#         11     18587.28
#         12     18113.73
# 1003    8       8565.21
#         9      12468.87
#         10     14768.14
#         11     11356.89
#         12     10121.53
# 1004    5      13403.98
#         6      17600.02
#         7      22229.58
#         8      28584.37
#         9      15109.03
#         10     18475.44
#         11     15616.02
#         12     18021.04

# %% [markdown]
# **Вывод к шагу 2**
# На шаге 2:
# - привели столбцы 'reg_date', 'churn_date' из датафрейма users, 'call_date' из датафрейма calls, 'message_date' из датафрейма messages и 'sessions_date' из датафрейма sessions к типу данных datetime64;
# - округлили значения столбца 'duration' датафрейма calls в большую сторону до целого значения, так как минуты в тарифе учитываются с подобным округлением;
# - удалили столбец 'Unnamed: 0' из датафрейма sessions;
# - создали столбцы 'month' с номером месяца для датафреймов calls, messages, sessions;
# - посчитали количество сделанных звонков разговора для каждого пользователя по месяцам в датафрейме calls_per_month;
# - посчитали количество израсходованных минут разговора для каждого пользователя по месяцам в датафрейме minutes_per_month;
# - посчитали количество отправленных сообщений по месяцам для каждого пользователя в датафрейме messages_per_month;
# - посчитали количество потраченных мегабайт по месяцам для каждого пользователя в датафрейме sessions_per_month.

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Объединяем все посчитанные выше значения в один датафрейм `user_behavior`.
# Для каждой пары «пользователь — месяц» будут доступны информация о тарифе, количестве звонков, сообщений и потраченных мегабайтах.

# %%
user_behavior = calls_per_month\
    .merge(messages_per_month, left_index=True, right_index=True, how='outer')\
    .merge(sessions_per_month, left_index=True, right_index=True, how='outer')\
    .merge(minutes_per_month, left_index=True, right_index=True, how='outer')\
    .reset_index()\
    .merge(users, how='left', left_on='user_id', right_on='user_id')\

user_behavior.head()
# Out:
#    user_id  month  calls  messages   mb_used  minutes  age churn_date  \
# 0     1000      5   22.0      22.0   2253.49    159.0   52        NaT
# 1     1000      6   43.0      60.0  23233.77    172.0   52        NaT
# 2     1000      7   47.0      75.0  14003.64    340.0   52        NaT
# 3     1000      8   52.0      81.0  14055.93    408.0   52        NaT
# 4     1000      9   58.0      57.0  14568.91    466.0   52        NaT
#
#         city first_name  last_name   reg_date tariff
# 0  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4  Краснодар     Рафаил  Верещагин 2018-05-25  ultra

# %% [markdown]
# Проверим пропуски в таблице `user_behavior` после объединения:

# %%
user_behavior.isna().sum()
# Out:
# user_id          0
# month            0
# calls           40
# messages       497
# mb_used         11
# minutes         40
# age              0
# churn_date    3027
# city             0
# first_name       0
# last_name        0
# reg_date         0
# tariff           0
# dtype: int64

# %% [markdown]
# Заполним образовавшиеся пропуски в данных:

# %%
user_behavior['calls'] = user_behavior['calls'].fillna(0)
user_behavior['minutes'] = user_behavior['minutes'].fillna(0)
user_behavior['messages'] = user_behavior['messages'].fillna(0)
user_behavior['mb_used'] = user_behavior['mb_used'].fillna(0)

# %% [markdown]
# Присоединяем информацию о тарифах

# %%
# переименование столбца tariff_name на более простое tariff

tariffs = tariffs.rename(
    columns={
        'tariff_name': 'tariff'
    }
)

# %%
user_behavior = user_behavior.merge(tariffs, on='tariff')

# %% [markdown]
# Считаем количество минут разговора, сообщений и мегабайт, превышающих включённые в тариф

# %%
user_behavior['paid_minutes'] = user_behavior['minutes'] - user_behavior['minutes_included']
user_behavior['paid_messages'] = user_behavior['messages'] - user_behavior['messages_included']
user_behavior['paid_mb'] = user_behavior['mb_used'] - user_behavior['mb_per_month_included']

for col in ['paid_messages', 'paid_minutes', 'paid_mb']:
    user_behavior.loc[user_behavior[col] < 0, col] = 0

# %% [markdown]
# Переводим превышающие тариф мегабайты в гигабайты и сохраняем в столбец `paid_gb`

# %%
user_behavior['paid_gb'] = np.ceil(user_behavior['paid_mb'] / 1024).astype(int)

# %% [markdown]
# Считаем выручку за минуты разговора, сообщения и интернет

# %%
user_behavior['cost_minutes'] = user_behavior['paid_minutes'] * user_behavior['rub_per_minute']
user_behavior['cost_messages'] = user_behavior['paid_messages'] * user_behavior['rub_per_message']
user_behavior['cost_gb'] = user_behavior['paid_gb'] * user_behavior['rub_per_gb']

# %% [markdown]
# Считаем помесячную выручку с каждого пользователя, она будет храниться в столбце `total_cost`

# %%
user_behavior['total_cost'] = \
      user_behavior['rub_monthly_fee']\
    + user_behavior['cost_minutes']\
    + user_behavior['cost_messages']\
    + user_behavior['cost_gb']

# %%
user_behavior.tail(10) # отобразим последние 10 строк таблицы user_behavior
# Out:
#       user_id  month  calls  messages   mb_used  minutes  age churn_date  \
# 3204     1497     11   64.0      14.0  14156.08    371.0   32        NaT
# 3205     1497     12   71.0      17.0  19918.60    545.0   32        NaT
# 3206     1498      7   23.0      20.0   7476.24    175.0   68 2018-10-25
# 3207     1498      8   57.0      62.0  24235.21    400.0   68 2018-10-25
# 3208     1498      9   59.0      44.0  22134.41    471.0   68 2018-10-25
# 3209     1498     10   41.0      42.0  20579.36    247.0   68 2018-10-25
# 3210     1499      9    9.0      11.0   1845.75     70.0   35        NaT
# 3211     1499     10   68.0      48.0  17788.51    449.0   35        NaT
# 3212     1499     11   74.0      59.0  17963.31    612.0   35        NaT
# 3213     1499     12   69.0      66.0  13055.58    492.0   35        NaT
#
#              city first_name last_name   reg_date tariff  messages_included  \
# 3204    Челябинск   Каролина    Агеева 2018-10-09  smart                 50
# ...

# %% [markdown]
# Датафрейм `stats_df` для каждой пары «месяц — тариф» будет хранить основные характеристики

# %%
# сохранение статистических метрик для каждой пары месяц-тариф
# в одной таблице stats_df (среднее значение, стандартное отклонение, медиана)

stats_df = user_behavior.pivot_table(
            index=['month', 'tariff'],\
            values=['calls', 'minutes', 'messages', 'mb_used'],\
            aggfunc=['mean', 'std', 'median']\
).round(2).reset_index()

stats_df.columns=['month', 'tariff', 'calls_mean', 'sessions_mean', 'messages_mean', 'minutes_mean',
                                     'calls_std',  'sessions_std', 'messages_std', 'minutes_std',
                                     'calls_median', 'sessions_median', 'messages_median',  'minutes_median']

stats_df.head(10)
# Out:
#    month tariff  calls_mean  sessions_mean  messages_mean  minutes_mean  \
# 0      1  smart       27.68        8513.72          18.24        203.85
# 1      1  ultra       59.44       13140.68          33.78        428.11
# 2      2  smart       40.19       11597.05          24.09        298.69
# 3      2  ultra       41.54       11775.94          21.96        297.12
# 4      3  smart       54.32       15104.16          31.86        390.05
# 5      3  ultra       67.68       17535.55          32.30        489.65
# 6      4  smart       51.31       13462.18          30.74        367.13
# 7      4  ultra       64.09       16828.13          31.56        458.02
# 8      5  smart       55.24       15805.18          33.77        387.36
# 9      5  ultra       72.51       19363.15          37.85        510.33
#
#    calls_std  sessions_std  messages_std  minutes_std  calls_median  \
# 0      20.81       6444.68         16.20       154.23          20.5
# ...

# %% [markdown]
# Также создадим датафрейм total_cost_stats_df, в котором будут храниться статистические метрики (среднее значение, стандартное отклонение, медиана) для помесячной выручки каждой пары «месяц — тариф».

# %%
total_cost_stats_df= user_behavior.pivot_table(
            index=['month', 'tariff'],\
            values=['total_cost'],\
            aggfunc=['mean', 'std', 'median']\
).round(2).reset_index()

total_cost_stats_df.columns=['month', 'tariff', 'total_cost_mean',
                                     'total_cost_std',
                                     'total_cost_median']

total_cost_stats_df.head()
# Out:
#    month tariff  total_cost_mean  total_cost_std  total_cost_median
# 0      1  smart           721.32          438.77              550.0
# 1      1  ultra          1950.00            0.00             1950.0
# 2      2  smart           827.60          540.70              550.0
# 3      2  ultra          1975.00           84.70             1950.0
# 4      3  smart          1164.62          698.03              886.0

# %% [markdown]
# **Отобразим количество клиентов на тарифах 'smart' и 'ultra'**

# %%
user_behavior.groupby('tariff').agg({'user_id':'count'})
# Out:
#         user_id
# tariff
# smart      2229
# ultra       985

# %% [markdown]
# **Рассчитаем, какое количество пользователей расторгли договор**

# %%
f"Договор расторгли {users['churn_date'].count() / users['churn_date'].shape[0]:.2%} клиентов датасета."
# Out:
# 'Договор расторгли 7.60% клиентов датасета.'

# %%
f"Договор расторгли {(users[users['tariff']=='smart']['churn_date'].count() / users[users['tariff']=='smart']['churn_date'].shape[0]):.2%} клиентов на тарифе 'smart'."
# Out:
# "Договор расторгли 6.55% клиентов на тарифе 'smart'."

# %%
f"Договор расторгли {(users[users['tariff']=='ultra']['churn_date'].count() / users[users['tariff']=='ultra']['churn_date'].shape[0]):.2%} клиентов на тарифе 'ultra'."
# Out:
# "Договор расторгли 10.07% клиентов на тарифе 'ultra'."

# %% [markdown]
# **Рассмотрим количество звонков, совершённых клиентами оператора связи**

# %% [markdown]
# Распределение среднего количества звонков по видам тарифов и месяцам

# %%
ax = sns.barplot(x='month',
            y='calls_mean',
            hue="tariff",
            data=stats_df,
            palette=['lightblue', 'blue'])

ax.set_title('Распределение количества звонков по видам тарифов и месяцам')
ax.set(xlabel='Номер месяца', ylabel='Среднее количество звонков');

# %%
user_behavior.groupby('tariff')['calls'].plot(kind='hist', bins=35, alpha=0.5)
plt.legend(['Smart', 'Ultra'])
plt.xlabel('Количество звонков')
plt.ylabel('Количество клиентов')
plt.title('Гистограмма распределения количества звонков в месяц по видам тарифов')
plt.show();

# %% [markdown]
# **Рассмотрим, какое количество минут тратят пользователи разных тарифов**

# %% [markdown]
# Распределение средней продолжительности звонков по видам тарифов и месяцам

# %%
ax = sns.barplot(x='month',
            y='minutes_mean',
            hue="tariff",
            data=stats_df,
            palette=['lightblue', 'blue'])

ax.set_title('Распределение продолжительности звонков по видам тарифов и месяцам')
ax.set(xlabel='Номер месяца', ylabel='Средняя продолжительность звонков');

# %%
user_behavior[user_behavior['tariff'] =='smart']['minutes'].hist(bins=35, alpha=0.5, color='green')
user_behavior[user_behavior['tariff'] =='ultra']['minutes'].hist(bins=35, alpha=0.5, color='blue')
plt.legend(['Smart', 'Ultra'])
plt.xlabel('Продолжительность звонков')
plt.ylabel('Количество клиентов')
plt.title('Гистограмма распределения продолжительности звонков по видам тарифов')
plt.show();

# %% [markdown]
# Средняя длительность разговоров у абонентов тарифа 'ultra' больше, чем у абонентов тарифа 'smart'. В течение года пользователи обоих тарифов увеличивают среднюю продолжительность своих разговоров. Рост средней длительности разговоров у абонентов тарифа 'smart' равномерный в течение года. Пользователи тарифа 'ultra' не проявляют подобной линейной стабильности.

# %% [markdown]
# **Рассмотрим, какое количество сообщений отправляют клиенты**

# %% [markdown]
# Распределение среднего количества сообщений по видам тарифов и месяцам

# %%
ax = sns.barplot(x='month',
            y='messages_mean',
            hue="tariff",
            data=stats_df,
            palette=['lightblue', 'blue']
)

ax.set_title('Распределение количества сообщений по видам тарифов и месяцам')
ax.set(xlabel='Номер месяца', ylabel='Среднее количество сообщений');

# %%
user_behavior[user_behavior['tariff'] =='smart']['messages'].hist(bins=35, alpha=0.5, color='green')
user_behavior[user_behavior['tariff'] =='ultra']['messages'].hist(bins=35, alpha=0.5, color='blue')
plt.legend(['Smart', 'Ultra'])
plt.xlabel('Количество сообщений')
plt.ylabel('Количество клиентов')
plt.title('Гистограмма распределения количества отправленных сообщений по видам тарифов');

# %% [markdown]
# В среднем пользователи тарифа 'ultra' отправляют больше сообщений. Количество сообщений в течение года на обоих тарифах растёт. В декабре в среднем на клиента было отправлено больше всего сообщений для обоих тарифах.

# %% [markdown]
# **Рассмотрим, какое количество трафика используют клиенты**

# %%
ax = sns.barplot(x='month',
            y='sessions_mean',
            hue='tariff',
            data=stats_df,
            palette=['lightblue', 'blue']
)

ax.set_title('Распределение количества потраченного трафика (Мб) по видам тарифов и месяцам')
ax.set(xlabel='Номер месяца', ylabel='Среднее количество мегабайт');

# %% [markdown]
# Сравнение потраченных мегабайт среди пользователей тарифов 'smart' и 'ultra'

# %%
user_behavior[user_behavior['tariff'] =='smart']['mb_used'].hist(bins=35, alpha=0.5, color='green')
user_behavior[user_behavior['tariff'] =='ultra']['mb_used'].hist(bins=35, alpha=0.5, color='blue')
plt.legend(['Smart', 'Ultra'])
plt.xlabel('Количество потраченных мегабайт')
plt.ylabel('Количество клиентов')
plt.title('Гистограмма распределения количества потраченных мегабайт по видам тарифов');

# %% [markdown]
# Меньше всего пользователи использовали интернет в январе, феврале и апреле. Чаще всего абоненты тарифа 'smart' тратят 15–17 Гб, а абоненты тарифного плана 'ultra' — 19–21 ГБ.

# %% [markdown]
# **Рассмотрим среднемесячную выручку, получаемую с одного абонента**

# %% [markdown]
# Распределение среднемесячной выручки с каждого пользователя по видам тарифов и месяцам

# %%
ax = sns.barplot(x='month',
            y='total_cost_mean',
            hue='tariff',
            data=total_cost_stats_df,
            palette=['lightblue', 'blue']
)

ax.set_title('Распределение среднемесячной выручки с абонента по видам тарифов и месяцам')
ax.set(xlabel='Номер месяца', ylabel='среднемесячной выручки выручка с абонента');

# %%
user_behavior[user_behavior['tariff'] =='smart']['total_cost'].hist(bins=10, alpha=0.5, color='green')
user_behavior[user_behavior['tariff'] =='ultra']['total_cost'].hist(bins=10, alpha=0.5, color='blue')
plt.legend(['Smart', 'Ultra'])
plt.xlabel('Среднемесячная выручка с абонента')
plt.ylabel('Количество клиентов')
plt.title('Гистограмма распределения среднемесячной выручки с абонента по видам тарифов');

# %% [markdown]
# Видим, что среднемесячная выручка с абонента по тарифу 'smart' для клиента возрастает в течение года; это связано с тем, что клиенты используют всё больше дополнительных минут, смс и интернета, не включённых в данный тариф. По тарифу 'ultra' среднемесячная выручка с абонента остаётся стабильной в течение года. В каждом из месяцев среднемесячная выручка с абонента тарифа 'ultra' была выше, чем среднемесячная выручка с абонента тарифа 'smart'. Однако на гистограмме видим, что есть клиенты тарифа 'smart', которые платили за услуги связи больше, чем клиенты тарифа 'ultra'.

# %% [markdown]
# **Вывод к шагу 3**
# На шаге 3:
# - объединили все полученные ранее значения в один датафрейм user_behavior, где для каждой пары "пользователь-месяц" доступна информация о тарифе, количестве звонков, сообщений и потраченных мегабайтах;
# - заменили пропуски нулями в датафрейме user_behavior;
# - посчитали количество минут разговора, сообщений и мегабайт, превышающих включённые в тариф; для этого создали в датафрейме user_behavior столбцы: 'padi_minutes',  'paid_messages', 'paid_mb' соответственно;
# - в датафрейме user_behavior создали столбец 'paid_gb', в котором перевели превышающие тариф мегабайты в гигабайты;
# - в датафрейме user_behavior создали столбцы 'cost_minutes', 'cost_messages', 'cost_gb' с выручкой за минуты разговора, сообщения и интернет, которые превышают установленные значения для тарифа;
# - в датафрейме user_behavior создали столбец 'total_cost', в котором посчитали помесячную выручку с каждого пользователя;
# - создали датафрейм stats_df, где для каждой пары "месяц-тариф" хранится среднее значение, стандартное отклонение и медиана для количества звонков, минут разговора, сообщений и мегабайт интернета, которые используют клиенты оператора связи;
# - создали датафрейм total_cost_stats_df, в котором хранится среднее значение, стандартное отклонение и медиана для помесячной выручки каждой пары "месяц-тариф.
#
# Выяснили, что:
# - на тарифе 'smart' - 2229 клиентов, на тарифе 'ultra' - 985 клиентов;
# - договор расторгли 7.6% клиентов датасета. На тарифе 'smart' - 6.55%; на тарифе 'ultra' - 10.07%;
# - средняя длительность разговоров у абонентов тарифа 'ultra' больше, чем у абонентов тарифа 'smart'. В течение года пользователи обоих тарифов увеличивают среднюю продолжительность своих разговоров. Рост средней длительности разговоров у абонентов тарифа 'smart' равномерный в течение года. Пользователи тарифа 'ultra' не проявляют подобной линейной стабильности;
# - в среднем пользователи тарифа 'ultra' отправляют больше сообщений . Количество сообщений в течение года на обоих тарифах растёт. В декабре в среднем на клиента было отправлено больше всего сообщений для обоих тарифах;
# - меньше всего пользователи использовали интернет в январе, феврале и апреле. Чаще всего абоненты тарифа smart тратят 15–17 Гб, а абоненты тарифного плана ultra — 19–21 ГБ;
# - среднемесячная выручка с абонента по тарифу 'smart' для клиента возрастает в течение года; это связано с тем, что клиенты используют всё больше дополнительных минут, смс и интернета, не включённых в данный тариф. По тарифу 'ultra' среднемесячная выручка с абонента остаётся стабильной в течение года. В каждом из месяцев среднемесячная выручка с абонента тарифа 'ultra' была выше, чем среднемесячная выручка с абонента тарифа 'smart'. Однако на гистограмме видим, что есть клиенты тарифа 'smart', которые платили за услуги связи больше, чем клиенты тарифа 'ultra'.

# %% [markdown]
# ## Шаг 4. Проверка гипотез

# %% [markdown]
# **Задание 28.** Проверка гипотезы: средняя выручка пользователей тарифов «ultra» и «smart» различается;
#
# ```
# H_0: Выручка (total_cost) пользователей "Ультра" = выручка (total_cost) пользователей "Смарт"`
# H_a: Выручка (total_cost) пользователей "Ультра" ≠ выручка (total_cost) пользователей "Смарт"`
# alpha = 0.05
# ```

# %%
# results - вызов метода для проверки гипотезы
results = st.ttest_ind(user_behavior[user_behavior['tariff']=='smart']['total_cost'],
                       user_behavior[user_behavior['tariff']=='ultra']['total_cost'],
                       equal_var=False)
# alpha - задаём значение уровня значимости
alpha = 0.05
# вывод значения p-value на экран
print(results.pvalue)
# условный оператор с выводом строки с ответом
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# 4.2606313931076085e-250
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Задание 29.** Проверка гипотезы: средняя выручка с пользователей из Москвы отличается от выручки c пользователей других регионов;
#
# ```
# H_0: Выручка (total_cost) пользователей из Москвы = выручка (total_cost) пользователей не из Москвы`
# H_1: Выручка (total_cost) пользователей из Москвы ≠ выручка (total_cost) пользователей не из Москвы`
# alpha = 0.05
# ```

# %%
# results - вызов метода для проверки гипотезы
results = st.ttest_ind(user_behavior.query('city=="Москва"')['total_cost'],
                      user_behavior.query('city!="Москва"')['total_cost'],
                      equal_var=False)
# alpha - задаём значение уровня значимости
alpha = 0.05
# вывод значения p-value на экран
print(results.pvalue)
# условный оператор с выводом строки с ответом
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# 0.5257376663729298
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# **Вывод к шагу 4**
# На шаге 4 проверили следующие нулевые гипотезы:
# - Среднемесячная выручка с абонента на тарифе "ultra" равна среднемесячной выручке с абонента на тарифа "smart". Отвергли данную нулевую гипотезу.
# - Среднемесячная выручка с абонента из Москвы равна среднемесячной выручке абонента не из Москвы. Не получилось отвергнуть данную нулевую гипотезу.

# %% [markdown]
# ## Шаг 5. Общий вывод
# На шаге 1 загрузили датафреймы calls, sessions, messages, tariffs и users и отобразили по ним основную информацию.
#
# На шаге 2:
# - привели столбцы 'reg_date', 'churn_date' из датафрейма users, 'call_date' из датафрейма calls, 'message_date' из датафрейма messages и 'sessions_date' из датафрейма sessions к типу данных datetime64;
# - округлили значения столбца 'duration' датафрейма calls в большую сторону до целого значения, так как минуты в тарифе учитываются с подобным округлением;
# - удалили столбец 'Unnamed: 0' из датафрейма sessions;
# - создали столбцы 'month' с номером месяца для датафреймов calls, messages, sessions;
# - посчитали количество сделанных звонков разговора для каждого пользователя по месяцам в датафрейме calls_per_month;
# - посчитали количество израсходованных минут разговора для каждого пользователя по месяцам в датафрейме minutes_per_month;
# - посчитали количество отправленных сообщений по месяцам для каждого пользователя в датафрейме messages_per_month;
# - посчитали количество потраченных мегабайт по месяцам для каждого пользователя в датафрейме sessions_per_month.
#
# На шаге 3:
# - объединили все полученные ранее значения в один датафрейм user_behavior, где для каждой пары "пользователь-месяц" доступна информация о тарифе, количестве звонков, сообщений и потраченных мегабайтах;
# - заменили пропуски нулями в датафрейме user_behavior;
# - посчитали количество минут разговора, сообщений и мегабайт, превышающих включённые в тариф; для этого создали в датафрейме user_behavior столбцы: 'padi_minutes',  'paid_messages', 'paid_mb' соответственно;
# - в датафрейме user_behavior создали столбец 'paid_gb', в котором перевели превышающие тариф мегабайты в гигабайты;
# - в датафрейме user_behavior создали столбцы 'cost_minutes', 'cost_messages', 'cost_gb' с выручкой за минуты разговора, сообщения и интернет, которые превышают установленные значения для тарифа;
# - в датафрейме user_behavior создали столбец 'total_cost', в котором посчитали помесячную выручку с каждого пользователя;
# - создали датафрейм stats_df, где для каждой пары "месяц-тариф" хранится среднее значение, стандартное отклонение и медиана для количества звонков, минут разговора, сообщений и мегабайт интернета, которые используют клиенты оператора связи;
# - создали датафрейм total_cost_stats_df, в котором хранится среднее значение, стандартное отклонение и медиана для помесячной выручки каждой пары "месяц-тариф.
#
# Выяснили, что:
# - на тарифе 'smart' - 2229 клиентов, на тарифе 'ultra' - 985 клиентов;
# - договор расторгли 7.6% клиентов датасета. На тарифе 'smart' - 6.55%; на тарифе 'ultra' - 10.07%;
# - средняя длительность разговоров у абонентов тарифа 'ultra' больше, чем у абонентов тарифа 'smart'. В течение года пользователи обоих тарифов увеличивают среднюю продолжительность своих разговоров. Рост средней длительности разговоров у абонентов тарифа 'smart' равномерный в течение года. Пользователи тарифа 'ultra' не проявляют подобной линейной стабильности;
# - в среднем пользователи тарифа 'ultra' отправляют больше сообщений . Количество сообщений в течение года на обоих тарифах растёт. В декабре в среднем на клиента было отправлено больше всего сообщений для обоих тарифах;
# - меньше всего пользователи использовали интернет в январе, феврале и апреле. Чаще всего абоненты тарифа smart тратят 15–17 Гб, а абоненты тарифного плана ultra — 19–21 ГБ;
# - среднемесячная выручка с абонента по тарифу 'smart' для клиента возрастает в течение года; это связано с тем, что клиенты используют всё больше дополнительных минут, смс и интернета, не включённых в данный тариф. По тарифу 'ultra' среднемесячная выручка с абонента остаётся стабильной в течение года. В каждом из месяцев среднемесячная выручка с абонента тарифа 'ultra' была выше, чем среднемесячная выручка с абонента тарифа 'smart'. Однако на гистограмме видим, что есть клиенты тарифа 'smart', которые платили за услуги связи больше, чем клиенты тарифа 'ultra'.
#
# На шаге 4 проверили следующие нулевые гипотезы:
# - Среднемесячная выручка с абонента на тарифе "ultra" равна среднемесячной выручке с абонента на тарифа "smart". Отвергли данную нулевую гипотезу.
# - Среднемесячная выручка с абонента из Москвы равна среднемесячной выручке абонента не из Москвы. Не получилось отвергнуть данную нулевую гипотезу.
